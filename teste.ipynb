# %% [markdown]
# # **Tipos de Variáveis em Análise de Dados**
#
# Em estatística e ciência de dados, as variáveis podem ser classificadas em diferentes tipos com base na natureza dos dados que representam.
#
# ## **1. Variáveis Qualitativas (Categóricas)**
# São aquelas que expressam categorias ou atributos sem uma ordem numérica significativa.
#
# ### **a) Nominais**
# - Não possuem uma ordem ou hierarquia.
# - Exemplo: Gênero (Masculino, Feminino), Cores (Azul, Verde, Vermelho).
#
# ### **b) Ordinais**
# - Possuem uma ordem ou hierarquia, mas sem uma diferença numérica bem definida entre os valores.
# - Exemplo: Nível de escolaridade (Fundamental, Médio, Superior), Classificação de satisfação (Ruim, Regular, Bom, Ótimo).
#
# ---
#
# ## **2. Variáveis Quantitativas (Numéricas)**
# São aquelas representadas por números e permitem operações matemáticas.
#
# ### **a) Discretas**
# - Assumem valores inteiros e contáveis.
# - Exemplo: Número de filhos, Quantidade de carros em um estacionamento.
#
# ### **b) Contínuas**
# - Podem assumir qualquer valor dentro de um intervalo, incluindo números decimais.
# - Exemplo: Altura (1,75m), Peso (68,5 kg), Temperatura (22,3°C).
#
# ---
#
# ## **3. Como Identificar o Tipo de Variável?**
# Para determinar o tipo de uma variável, pergunte-se:
# ✔ **Os valores são categorias sem ordem?** → **Qualitativa Nominal**
# ✔ **Os valores têm ordem, mas não são numéricos?** → **Qualitativa Ordinal**
# ✔ **Os valores são numéricos inteiros e contáveis?** → **Quantitativa Discreta**
# ✔ **Os valores são numéricos e podem ter casas decimais?** → **Quantitativa Contínua**
#
# Compreender os tipos de variáveis é essencial para escolher as técnicas estatísticas corretas e interpretar os dados corretamente. 🚀

# %%
import pandas as pd 
import numpy as np
import seaborn as sns

# %%
dados = pd.read_csv("dados.csv")

dados
# Out:
#        UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura
# 0      11     0     23    8              12    800  1.603808
# 1      11     1     23    2              12   1150  1.739790
# 2      11     1     35    8              15    880  1.760444
# 3      11     0     46    2               6   3500  1.783158
# 4      11     1     47    8               9    150  1.690631
# ...    ..   ...    ...  ...             ...    ...       ...
# 76835  53     1     46    2              11    812  1.687030
# 76836  53     0     30    4               7   1500  1.792934
# 76837  53     0     32    8              12   1300  1.830587
# 76838  53     0     57    8               4   1500  1.726344
# 76839  53     0     38    8               4    900  1.658305
#
# [76840 rows x 7 columns]

# %%
dados.describe()
# Out:
#                  UF          Sexo         Idade           Cor  Anos de Estudo  \
# count  76840.000000  76840.000000  76840.000000  76840.000000    76840.000000
# mean      31.912962      0.307002     44.071421      5.032613        9.469664
# std       11.147830      0.461253     12.480583      2.857118        4.539929
# min       11.000000      0.000000     13.000000      0.000000        1.000000
# 25%       25.000000      0.000000     34.000000      2.000000        6.000000
# 50%       31.000000      0.000000     43.000000      4.000000       11.000000
# 75%       41.000000      1.000000     53.000000      8.000000       12.000000
# max       53.000000      1.000000     99.000000      8.000000       17.000000
#
#                Renda        Altura
# count   76840.000000  76840.000000
# mean     2000.383199      1.699512
# std      3323.387730      0.079717
# min         0.000000      1.339245
# 25%       788.000000      1.645785
# 50%      1200.000000      1.699325
# ...

# %%
dados.isnull().sum()
# Out:
# UF                0
# Sexo              0
# Idade             0
# Cor               0
# Anos de Estudo    0
# Renda             0
# Altura            0
# dtype: int64

# %%
dicionario_sexo = {0: 'Masculino', 1: 'Feminino'}

dicionario_cor = {
    0: 'Indígena',
    2: 'Branca',
    4: 'Preta',
    6: 'Amarela',
    8: 'Parda'
}

dicionario_uf = {
    11: 'Rondônia',
    12: 'Acre',
    13: 'Amazonas',
    14: 'Roraima',
    15: 'Pará',
    16: 'Amapá',
    17: 'Tocantins',
    21: 'Maranhão',
    22: 'Piauí',
    23: 'Ceará',
    24: 'Rio Grande do Norte',
    25: 'Paraíba',
    26: 'Pernambuco',
    27: 'Alagoas',
    28: 'Sergipe',
    29: 'Bahia',
    31: 'Minas Gerais',
    32: 'Espírito Santo',
    33: 'Rio de Janeiro',
    35: 'São Paulo',
    41: 'Paraná',
    42: 'Santa Catarina',
    43: 'Rio Grande do Sul',
    50: 'Mato Grosso do Sul',
    51: 'Mato Grosso',
    52: 'Goiás',
    53: 'Distrito Federal'
}

print(dicionario_sexo)
print(dicionario_cor)
print(dicionario_uf)
# Out:
# {0: 'Masculino', 1: 'Feminino'}
# {0: 'Indígena', 2: 'Branca', 4: 'Preta', 6: 'Amarela', 8: 'Parda'}
# {11: 'Rondônia', 12: 'Acre', 13: 'Amazonas', 14: 'Roraima', 15: 'Pará', 16: 'Amapá', 17: 'Tocantins', 21: 'Maranhão', 22: 'Piauí', 23: 'Ceará', 24: 'Rio Grande do Norte', 25: 'Paraíba', 26: 'Pernambuco', 27: 'Alagoas', 28: 'Sergipe', 29: 'Bahia', 31: 'Minas Gerais', 32: 'Espírito Santo', 33: 'Rio de Janeiro', 35: 'São Paulo', 41: 'Paraná', 42: 'Santa Catarina', 43: 'Rio Grande do Sul', 50: 'Mato Grosso do Sul', 51: 'Mato Grosso', 52: 'Goiás', 53: 'Distrito Federal'}

# %% [markdown]
# #### Regra de Sturges
#
# # $$k = 1 + \frac {10}{3}\log_{10}n$$
#
# ### A Regra de Sturges é um método empírico utilizado em estatística para determinar o número ideal de classes (ou intervalos) a serem usados na construção de um histograma
#
#
#
# k = 1 + 3,322 * log(n)
#
#
#
# k é o número de classes.
# n é o número total de observações no conjunto de dados.
# log é o logaritmo na base 10.

# %%
x = dados.shape[0]
x
# Out:
# 76840

# %%
k = 1+(10/3)*np.log10(x)
k
# Out:
# np.float64(17.285291187298853)

# %%
renda_bins = pd.cut(dados.Renda, bins=17, include_lowest=True)

contagem_renda = renda_bins.value_counts(sort=False)

print(contagem_renda)
# Out:
# Renda
# (-200.001, 11764.706]       75594
# (11764.706, 23529.412]       1022
# (23529.412, 35294.118]        169
# (35294.118, 47058.824]         19
# (47058.824, 58823.529]         16
# (58823.529, 70588.235]          5
# (70588.235, 82352.941]          4
# (82352.941, 94117.647]          1
# (94117.647, 105882.353]         6
# (105882.353, 117647.059]        0
# (117647.059, 129411.765]        1
# (129411.765, 141176.471]        0
# (141176.471, 152941.176]        0
# (152941.176, 164705.882]        0
# (164705.882, 176470.588]        0
# (176470.588, 188235.294]        0
# (188235.294, 200000.0]          3
# Name: count, dtype: int64

# %%
frequencia = pd.value_counts(
    pd.cut(
        x = dados.Renda,
        bins = 17,
        include_lowest = True
    ),
    sort = False
    )
# Out:
# C:\Users\arthur.lacerda_ipnet\AppData\Local\Temp\ipykernel_16896\2542858371.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   frequencia = pd.value_counts(

# %%
percentual = pd.value_counts(
    pd.cut(
        x = dados.Renda,
        bins = 17,
        include_lowest = True
    ),
    sort = False,
    normalize = True
)
percentual
# Out:
# C:\Users\arthur.lacerda_ipnet\AppData\Local\Temp\ipykernel_16896\2870492360.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   percentual = pd.value_counts(
# Renda
# (-200.001, 11764.706]       0.983784
# (11764.706, 23529.412]      0.013300
# (23529.412, 35294.118]      0.002199
# (35294.118, 47058.824]      0.000247
# (47058.824, 58823.529]      0.000208
# (58823.529, 70588.235]      0.000065
# (70588.235, 82352.941]      0.000052
# (82352.941, 94117.647]      0.000013
# (94117.647, 105882.353]     0.000078
# (105882.353, 117647.059]    0.000000
# (117647.059, 129411.765]    0.000013
# (129411.765, 141176.471]    0.000000
# (141176.471, 152941.176]    0.000000
# (152941.176, 164705.882]    0.000000
# (164705.882, 176470.588]    0.000000
# (176470.588, 188235.294]    0.000000
# (188235.294, 200000.0]      0.000039
# Name: proportion, dtype: float64

# %%
dist_freq_qualitativas_amplitude_fixa = pd.DataFrame(
    {"Frequência": frequencia, "Porcentagem (%)": percentual}
)
dist_freq_qualitativas_amplitude_fixa
# Out:
#                           Frequência  Porcentagem (%)
# Renda
# (-200.001, 11764.706]          75594         0.983784
# (11764.706, 23529.412]          1022         0.013300
# (23529.412, 35294.118]           169         0.002199
# (35294.118, 47058.824]            19         0.000247
# (47058.824, 58823.529]            16         0.000208
# (58823.529, 70588.235]             5         0.000065
# (70588.235, 82352.941]             4         0.000052
# (82352.941, 94117.647]             1         0.000013
# (94117.647, 105882.353]            6         0.000078
# (105882.353, 117647.059]           0         0.000000
# (117647.059, 129411.765]           1         0.000013
# (129411.765, 141176.471]           0         0.000000
# (141176.471, 152941.176]           0         0.000000
# (152941.176, 164705.882]           0         0.000000
# (164705.882, 176470.588]           0         0.000000
# (176470.588, 188235.294]           0         0.000000
# ...

# %% [markdown]
# # **Média, Mediana e Moda**
#
# Em estatística descritiva, **média, mediana e moda** são medidas de tendência central, utilizadas para resumir um conjunto de dados.
#
# ---
#
# ## **1. Média**
#
# A **média aritmética** é calculada somando todos os valores e dividindo pelo número total de elementos.
#
# ### **Fórmula da Média Aritmética**
# \[
# \bar{x} = \frac{\sum_{i=1}^{n} x_i}{n}
# \]
#
# Onde:
# - \(\bar{x}\) = média
# - \(x_i\) = cada valor do conjunto de dados
# - \(n\) = número total de elementos
#
# **Exemplo**: Se temos os números **3, 5, 7**, a média é:
# \[
# \bar{x} = \frac{3 + 5 + 7}{3} = \frac{15}{3} = 5
# \]
#
# ---
#
# ## **2. Mediana**
#
# A **mediana** é o valor central de um conjunto de dados ordenado.
#
# - Se a quantidade de elementos (\(n\)) for **ímpar**, a mediana é o valor central.
# - Se \(n\) for **par**, a mediana é a média dos dois valores centrais.
#
# **Exemplo (n ímpar)**: Para os números **2, 4, 7, 9, 11**, a mediana é **7**.
# **Exemplo (n par)**: Para os números **1, 3, 5, 7, 9, 11**, a mediana é:
# \[
# \frac{5 + 7}{2} = 6
# \]
#
# ---
#
# ## **3. Moda**
#
# A **moda** é o valor que mais se repete no conjunto de dados.
#
# - Pode haver **uma única moda (unimodal)**, **mais de uma moda (multimodal)** ou **nenhuma moda** se todos os valores forem distintos.
#
# **Exemplo**: Para os números **4, 5, 6, 5, 7, 5, 8**, a moda é **5** (pois aparece mais vezes).
#
# ---
#
# ## **Resumo das Diferenças**
#
# | Medida   | Descrição | Quando Usar? |
# |----------|----------|--------------|
# | **Média**   | Soma dos valores dividida pelo total | Útil para dados simétricos, sem valores extremos |
# | **Mediana** | Valor central dos dados ordenados | Melhor para dados com outliers (valores extremos) |
# | **Moda**    | Valor mais frequente | Útil para identificar padrões e repetições |
#
# Essas medidas ajudam a entender a distribuição dos dados e escolher a melhor forma de analisá-los.

# %%
media_anos_estudo = dados['Anos de Estudo'].mean()
media_renda = dados['Renda'].mean()
media_altura = dados['Altura'].mean()

mediana_anos_estudo = dados['Anos de Estudo'].median()
mediana_renda = dados['Renda'].median()
mediana_altura = dados['Altura'].median()

print(f"Média Anos de Estudo: {media_anos_estudo}")
print(f"Média Renda: {media_renda}")
print(f"Média Altura: {media_altura}")

print(f"Mediana Anos de Estudo: {mediana_anos_estudo}")
print(f"Mediana Renda: {mediana_renda}")
print(f"Mediana Altura: {mediana_altura}")
# Out:
# Média Anos de Estudo: 9.469664237376367
# Média Renda: 2000.3831988547631
# Média Altura: 1.6995124540575741
# Mediana Anos de Estudo: 11.0
# Mediana Renda: 1200.0
# Mediana Altura: 1.6993247325

# %%
moda_sexo = dados['Sexo'].mode()[0]
moda_cor = dados['Cor'].mode()[0]
moda_uf = dados['UF'].mode()[0]

moda_sexo_str = dicionario_sexo[moda_sexo]
moda_cor_str = dicionario_cor[moda_cor]
moda_uf_str = dicionario_uf[moda_uf]

print(f"Moda Sexo: {moda_sexo_str}")
print(f"Moda Cor: {moda_cor_str}")
print(f"Moda UF: {moda_uf_str}")
# Out:
# Moda Sexo: Masculino
# Moda Cor: Parda
# Moda UF: São Paulo

# %% [markdown]
# # **HISTOGRAMA**
#
# O **histograma** é a representação gráfica de uma distribuição de frequências.
# É um gráfico formado por um conjunto de retângulos colocados lado a lado, onde a área de cada retângulo é proporcional à frequência da classe que ele representa.
#
#
# ![image.png](attachment:image.png)
#
#
# bibliografia:
#
#
# https://gestaoprodutiva.com.br/histograma-o-que-e-como-fazer/

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

fig, axes = plt.subplots(2, 2, figsize=(15, 10))

sns.histplot(dados.Renda, bins=17, kde=True, ax=axes[0, 0], color="royalblue", line_kws={'color': 'mediumseagreen'})
axes[0, 0].set_title('Histograma da Renda')

sns.histplot(dados.Idade, bins=20, kde=True, ax=axes[0, 1], color="royalblue", line_kws={'color': 'mediumseagreen'})
axes[0, 1].set_title('Histograma da Idade')

sns.histplot(dados.Altura, bins=20, kde=True, ax=axes[1, 0], color="royalblue", line_kws={'color': 'mediumseagreen'})
axes[1, 0].set_title('Histograma da Altura')

sns.histplot(dados['Anos de Estudo'], bins=20, kde=True, ax=axes[1, 1], color="royalblue", line_kws={'color': 'mediumseagreen'})
axes[1, 1].set_title('Histograma dos Anos de Estudo')

plt.tight_layout()
plt.show()

sns.histplot(dados.Altura, kde=True, color="royalblue", line_kws={'color': 'mediumseagreen'})
plt.show()

# %% [markdown]
# # **Correlação e Coeficiente de Determinação (\( R^2 \))**
#
# ## **1. O que é Correlação?**
#
# A correlação mede o grau de associação entre duas variáveis e varia entre **-1 e 1**:
#
# - **\( r > 0 \)** → Correlação positiva (quando uma variável aumenta, a outra também aumenta).
# - **\( r < 0 \)** → Correlação negativa (quando uma variável aumenta, a outra diminui).
# - **\( r = 0 \)** → Nenhuma correlação (as variáveis não têm relação linear).
#
# ---
#
# ## **2. O que é \( R^2 \)?**
#
# O **coeficiente de determinação** (\( R^2 \)) indica **quanto da variação de uma variável pode ser explicada pela outra**. Ele é obtido elevando ao quadrado o coeficiente de correlação (\( r \)):
#
# \[
# R^2 = r^2
# \]
#
# ### **Interpretação de \( R^2 \)**
#
# - **\( R^2 = 1 \)** → A variável independente explica **100%** da variação da variável dependente.
# - **\( R^2 = 0.8 \)** → A variável independente explica **80%** da variação.
# - **\( R^2 = 0 \)** → Nenhuma explicação da variação da variável dependente.
#
# ⚠️ **Atenção**: Um \( R^2 \) alto indica que há relação entre as variáveis, mas **não significa que uma causa a outra**!
#
# ---
#
# O \( R^2 \) é amplamente usado em **regressão linear** para medir a qualidade do modelo e avaliar se os dados seguem um padrão possível

# %%
dados
# Out:
#        UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura
# 0      11     0     23    8              12    800  1.603808
# 1      11     1     23    2              12   1150  1.739790
# 2      11     1     35    8              15    880  1.760444
# 3      11     0     46    2               6   3500  1.783158
# 4      11     1     47    8               9    150  1.690631
# ...    ..   ...    ...  ...             ...    ...       ...
# 76835  53     1     46    2              11    812  1.687030
# 76836  53     0     30    4               7   1500  1.792934
# 76837  53     0     32    8              12   1300  1.830587
# 76838  53     0     57    8               4   1500  1.726344
# 76839  53     0     38    8               4    900  1.658305
#
# [76840 rows x 7 columns]

# %%
dados['Sexo'] = dados['Sexo'].replace(dicionario_sexo)
dados['Cor'] = dados['Cor'].replace(dicionario_cor)
dados['UF'] = dados['UF'].replace(dicionario_uf)

dados.head()
# Out:
#          UF       Sexo  Idade     Cor  Anos de Estudo  Renda    Altura
# 0  Rondônia  Masculino     23   Parda              12    800  1.603808
# 1  Rondônia   Feminino     23  Branca              12   1150  1.739790
# 2  Rondônia   Feminino     35   Parda              15    880  1.760444
# 3  Rondônia  Masculino     46  Branca               6   3500  1.783158
# 4  Rondônia   Feminino     47   Parda               9    150  1.690631

# %%
faixas_renda = [-np.inf, 1000, 3000, 10000, np.inf]
classes_sociais = ['Baixa', 'Média', 'Alta', 'Muito Alta']

dados['Classe Social'] = pd.cut(dados['Renda'], bins=faixas_renda, labels=classes_sociais, include_lowest=True)

dados.head()
# Out:
#          UF       Sexo  Idade     Cor  Anos de Estudo  Renda    Altura  \
# 0  Rondônia  Masculino     23   Parda              12    800  1.603808
# 1  Rondônia   Feminino     23  Branca              12   1150  1.739790
# 2  Rondônia   Feminino     35   Parda              15    880  1.760444
# 3  Rondônia  Masculino     46  Branca               6   3500  1.783158
# 4  Rondônia   Feminino     47   Parda               9    150  1.690631
#
#   Classe Social
# 0         Baixa
# 1         Média
# 2         Baixa
# 3          Alta
# 4         Baixa

# %%
dados_filtrados = dados[dados['Cor'].isin(['Preta', 'Branca'])]

plt.figure(figsize=(10, 6))
dados_amostrados = dados_filtrados.sample(frac=0.1, random_state=1)
scatter_plot = sns.scatterplot(data=dados_filtrados, x='Anos de Estudo', y='Renda', hue='Cor', palette='Set1')
scatter_plot.set_title('Gráfico de Dispersão: Renda vs Anos de Estudo (Preta e Branca)')
scatter_plot.set_xlabel('Anos de Estudo')
scatter_plot.set_ylabel('Renda')
plt.legend(title='Cor')
plt.show()

# %%
dados_filtrados_sexo = dados[dados['Sexo'].isin(['Masculino', 'Feminino'])]

plt.figure(figsize=(10, 6))
dados_amostrados = dados_filtrados_sexo.sample(frac=0.1, random_state=1)

scatter_plot_sexo = sns.scatterplot(data=dados_amostrados, x='Anos de Estudo', y='Renda', hue='Sexo', palette='Set1')
scatter_plot_sexo.set_title('Gráfico de Dispersão: Renda vs Anos de Estudo (Masculino e Feminino)')
scatter_plot_sexo.set_xlabel('Anos de Estudo')
scatter_plot_sexo.set_ylabel('Renda')
plt.legend(title='Sexo')
plt.show()

# %% [markdown]
# # Boxplot: Visualização Estatística de Distribuição
#
# ## O que é um Boxplot?
# O **Boxplot** (ou diagrama de caixa) é uma ferramenta estatística utilizada para visualizar a **distribuição de dados** de forma resumida. Ele destaca medidas como **mediana, quartis e valores atípicos**, sendo útil para comparar diferentes grupos.
#
# ---
#
# ## Componentes de um Boxplot
# Um boxplot é composto por:
#
# 1. **Mediana (linha dentro da caixa)**
#    - Representa o valor central dos dados (50% dos valores estão abaixo e 50% acima).
#
# 2. **Quartis (Q1 e Q3 - bordas da caixa)**
#    - **Q1 (1º quartil - 25%)**: 25% dos dados estão abaixo desse valor.
#    - **Q3 (3º quartil - 75%)**: 75% dos dados estão abaixo desse valor.
#    - A **diferença entre Q3 e Q1** é chamada de **Intervalo Interquartil (IQR)**.
#
# 3. **Bigodes (linhas fora da caixa)**
#    - Indicam a dispersão dos dados sem considerar outliers.
#    - Geralmente estendem-se até **1,5 × IQR** a partir dos quartis.
#
# 4. **Outliers (pontos individuais)**
#    - Valores **fora do intervalo esperado** (abaixo de Q1 - 1,5×IQR ou acima de Q3 + 1,5×IQR).
#    - Podem representar erros, exceções ou padrões interessantes.
#
# ![image.png](attachment:image.png)
#
# ---
#
# ## Exemplo de Boxplot no Python (usando Seaborn)
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# # Criando dados de exemplo
# import pandas as pd
# import numpy as np
#
# np.random.seed(10)
# dados = pd.DataFrame({
#     'Categoria': np.random.choice(['A', 'B', 'C'], 100),
#     'Valores': np.random.normal(50, 15, 100)  # Média = 50, Desvio Padrão = 15
# })
#
# # Criando o Boxplot
# plt.figure(figsize=(8,5))
# sns.boxplot(x='Categoria', y='Valores', data=dados, palette="Set2")
#
# # Configuração do gráfico
# plt.title("Boxplot das Categorias")
# plt.xlabel("Categoria")
# plt.ylabel("Valores")
# plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt



# Criando o Boxplot para Anos de Estudo por Cor
plt.figure(figsize=(10, 6))
sns.boxplot(data=dados, x='Cor', y='Anos de Estudo', palette='Set2')
plt.title('Boxplot: Anos de Estudo por Cor')
plt.xlabel('Cor')
plt.ylabel('Anos de Estudo')
plt.show()

# Criando o Boxplot para Anos de Estudo por Sexo
plt.figure(figsize=(10, 6))
sns.boxplot(data=dados, x='Sexo', y='Anos de Estudo', palette='Set2')
plt.title('Boxplot: Anos de Estudo por Sexo')
plt.xlabel('Sexo')
plt.ylabel('Anos de Estudo')
plt.show()
# Out:
# C:\Users\arthur.lacerda_ipnet\AppData\Local\Temp\ipykernel_11848\1207596636.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=dados, x='Cor', y='Anos de Estudo', palette='Set2')
# C:\Users\arthur.lacerda_ipnet\AppData\Local\Temp\ipykernel_11848\1207596636.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=dados, x='Sexo', y='Anos de Estudo', palette='Set2')

# %% [markdown]
# # Teste T de Student
#
# O Teste T de Student é um teste estatístico utilizado para comparar as médias de dois grupos e determinar se a diferença entre elas é estatisticamente significativa.
#
# ## Quando usar o Teste T?
# O teste T é aplicado quando queremos verificar se duas amostras são significativamente diferentes em relação a uma variável numérica.
#
# ### Exemplos:
# - Comparar anos de estudo entre pessoas de diferentes grupos.
# - Comparar salários entre homens e mulheres.
# - Comparar altura entre dois grupos.
#
# ## Tipos de Teste T
#
# 1. **Teste T para amostras independentes**
#    - Compara dois grupos diferentes (exemplo: "anos de estudo" entre dois grupos distintos).
#
# 2. **Teste T para amostras pareadas**
#    - Compara o mesmo grupo antes e depois de um tratamento (exemplo: comparar salários de um grupo antes e depois de um curso).
#
# 3. **Teste T para uma amostra**
#    - Compara a média de uma amostra com um valor fixo (exemplo: verificar se a média de renda de um grupo é diferente de um determinado valor).
#
# ## Hipóteses do Teste T
#
# - **Hipótese nula (H₀):** Não há diferença significativa entre as médias.
# - **Hipótese alternativa (H₁):** Há uma diferença significativa entre as médias.
#
# Se o p-valor for menor que 0.05, rejeitamos H₀ e consideramos que há diferença significativa.
#
# ![image.png](attachment:image.png)

# %%
from scipy.stats import ttest_ind

# Filtrando os dados para pessoas Negras (Preta)
dados_negras = dados[dados['Cor'] == 'Preta']
dados_nao_negras = dados[dados['Cor'] != 'Preta']

# Realizando o Teste T de Student
t_stat, p_value = ttest_ind(dados_negras['Anos de Estudo'], dados_nao_negras['Anos de Estudo'], equal_var=False)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_value}")

if p_value < 0.05:
    print("Rejeitamos a hipótese nula: Há diferença significativa nos anos de estudo entre pessoas Negras e não Negras.")
else:
    print("Não rejeitamos a hipótese nula: Não há diferença significativa nos anos de estudo entre pessoas Negras e não Negras.")
# Out:
# T-statistic: -13.316235144812001
# P-value: 3.886384125566786e-40
# Rejeitamos a hipótese nula: Há diferença significativa nos anos de estudo entre pessoas Negras e não Negras.

# %%
import numpy as np
from scipy.stats import t

import matplotlib.pyplot as plt

# Parâmetros para a distribuição T de Student
df = len(dados_negras) + len(dados_nao_negras) - 2  # graus de liberdade
x = np.linspace(-4, 4, 1000)
y = t.pdf(x, df)

# Plotando a distribuição T de Student
plt.figure(figsize=(12, 8))
plt.plot(x, y, label=f'T-distribution (df={df})', color='royalblue')
plt.axvline(t_stat, color='red', linestyle='--', label=f'T-statistic = {t_stat:.2f}')
plt.fill_between(x, y, where=(x >= t_stat), color='red', alpha=0.3)
plt.fill_between(x, y, where=(x <= -t_stat), color='red', alpha=0.3)
plt.title('Distribuição T de Student')
plt.xlabel('Valores de T')
plt.ylabel('Densidade de Probabilidade')
plt.legend()
plt.show()

# %% [markdown]
# # Introdução ao Machine Learning
#
# Machine Learning (ML) é um campo da inteligência artificial que permite que sistemas aprendam padrões a partir de dados e tomem decisões sem serem explicitamente programados. Os algoritmos de ML podem ser divididos em três categorias principais:
#
# - **Aprendizado Supervisionado:** O modelo aprende a partir de dados rotulados, onde há uma relação entre as entradas e as saídas desejadas.
# - **Aprendizado Não Supervisionado:** O modelo identifica padrões e estruturas nos dados sem rótulos pré-definidos.
# - **Aprendizado por Reforço:** O modelo aprende por meio de interações com o ambiente, recebendo recompensas ou penalidades com base em suas ações.
#
# Dentre os diversos algoritmos utilizados no aprendizado supervisionado, um dos mais poderosos e populares é o **Random Forest**.
#
# # Random Forest
#
# ## O que é Random Forest?
# Random Forest é um algoritmo de aprendizado supervisionado baseado em árvores de decisão. Ele constrói diversas árvores de decisão durante o treinamento e combina seus resultados para melhorar a precisão e reduzir o risco de overfitting.
#
# ## Como Funciona?
#
# O Random Forest segue uma abordagem conhecida como **ensemble learning**, onde vários modelos são combinados para obter previsões mais robustas. Seu funcionamento ocorre em três etapas principais:
#
# 1. **Criação de múltiplas árvores de decisão:** O algoritmo seleciona subconjuntos aleatórios dos dados de treinamento e treina uma árvore de decisão para cada um deles. Esse processo é chamado de **Bootstrap Sampling**.
# 2. **Predição por cada árvore:** Cada árvore faz uma previsão baseada nos dados que recebeu.
# 3. **Combinação dos resultados:** Para problemas de **classificação**, o resultado final é decidido por votação da maioria. Para **regressão**, a média das previsões das árvores é utilizada.
#
# ## Vantagens
#
# - Reduz o overfitting ao combinar múltiplas árvores.
# - Funciona bem com grandes volumes de dados e problemas complexos.
# - Pode lidar com variáveis categóricas e numéricas sem a necessidade de pré-processamento intenso.
# - Permite calcular a importância das variáveis, ajudando na interpretação dos dados.
#
# ## Desvantagens
#
# - Pode ser mais lento do que uma única árvore de decisão, pois cria múltiplos modelos.
# - Difícil de interpretar quando há um grande número de árvores, tornando-o menos transparente do que métodos mais simples.
#
# O Random Forest é amplamente utilizado em diversas áreas, como previsão de crédito, diagnóstico médico, análise de sentimento e muitas outras aplicações que exigem alta precisão e robustez na tomada de decisão.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

X = dados.drop(columns=['Anos de Estudo'])
y = dados['Anos de Estudo']

X = pd.get_dummies(X, drop_first=True)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

rf = RandomForestRegressor(n_estimators=100, random_state=42)

rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R^2 Score: {r2}')
# Out:
# Mean Squared Error: 13.462416840187403
# R^2 Score: 0.3560895026420634

# %%
importances = rf.feature_importances_
feature_names = X.columns
feature_importances = pd.DataFrame({'Feature': feature_names, 'Importance': importances})

color_features = feature_importances[feature_importances['Feature'].str.contains('Cor_')]

color_features = color_features.sort_values(by='Importance', ascending=False)

plt.figure(figsize=(12, 8))
sns.barplot(x='Importance', y='Feature', data=color_features, palette=sns.color_palette("Blues", n_colors=len(color_features)))
plt.title('Importância das Cores')
plt.xlabel('Importância')
plt.ylabel('Cores')
plt.show()

print(color_features)

# Avaliando o modelo
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R^2 Score: {r2}')
# Out:
# C:\Users\arthur.lacerda_ipnet\AppData\Local\Temp\ipykernel_16896\2448782599.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance', y='Feature', data=color_features, palette=sns.color_palette("Blues", n_colors=len(color_features)))
#          Feature  Importance
# 30    Cor_Branca    0.013254
# 32     Cor_Parda    0.011564
# 33     Cor_Preta    0.008377
# 31  Cor_Indígena    0.001336
# Mean Squared Error: 13.462416840187403
# R^2 Score: 0.3560895026420634

# %%
print(sex_features)
plt.figure(figsize=(12, 8))
sns.barplot(x='Importance', y='Feature', data=feature_importances, palette='Blues')
plt.title('Importância das Features')
plt.xlabel('Importância')
plt.ylabel('Features')
plt.show()
print(feature_importances)
# Out:
#            Feature  Importance
# 29  Sexo_Masculino     0.03885
# C:\Users\arthur.lacerda_ipnet\AppData\Local\Temp\ipykernel_16896\158765976.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance', y='Feature', data=feature_importances, palette='Blues')
#                      Feature  Importance
# 1                      Renda    0.352526
# 2                     Altura    0.227860
# 0                      Idade    0.163780
# 29            Sexo_Masculino    0.038850
# 30                Cor_Branca    0.013254
# 27              UF_São Paulo    0.012102
# 14           UF_Minas Gerais    0.011843
# 32                 Cor_Parda    0.011564
# 22         UF_Rio de Janeiro    0.010123
# 21      UF_Rio Grande do Sul    0.010057
# 6                   UF_Bahia    0.009767
# 18             UF_Pernambuco    0.009578
# ...
